# %% [markdown]
# <div align="center">
#
# # Default template:
# </div>

# %% [markdown]
# # 1. Notebook Title
# ## 2. Objective
#
# - Concept to be applied
# - What is being studied/modeled
#
# ## 3. Theory
#
# ---

# %% [markdown]
# <div align="center">
#
# ## 4. Python Application
# ## 5. Preview
# </div>
#
# ---

# %% [markdown]
# # 6. Interpretation
# # 7. Conclusion
#
# ---
