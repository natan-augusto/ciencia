# %% [markdown]
# <div align="center">
#
# # Unit Converter for the International System (SI)
# </div>
#
# ## Objective
# This notebook implements a converter based on **Chapter 1** of the book "Fundamentals of Physics" (Halliday & Resnick).
# - Fundamental SI units (meter, second, kilogram).
# - Metric prefixes (kilo, hecto, deca, deci, centi, milli...).
# - Using text boxes and operating with variables in Python.
#
# ---
# ## Theory
# This program applies the theory of converting physical quantities (length, time, and mass) between different units of the International System of Units (SI).
# According to the textbook:
#
# >"Incorporar um prefixo a uma unidade do SI tem o efeito de multiplicar a unidade pelo fator correspondente."
# >(Incorporating a prefix into an SI unit has the effect of multiplying the unit by the corresponding factor.)
#
# For example:
#
# - 1 kilometer (km) is $10^3$ meters, so to convert 5 km to meters, we calculate $5 \times 10^3 = 5000$ m.
# - 1 milligram (mg) is $10^{-6}$ kilograms, so to convert 2500 mg to kg, we calculate $2500 \times 10^{-6} = 0.0025$ kg.
#
# ## Prefixes used:
#
# - Multiples ($Factor > 1$):
#
# | Factor | Prefix | Symbol |
# | :--- | :---: | ---: |
# | $10^24$ | iota | Y |
# | $10^21$ | zeta | Z |
# | $10^18$ | exa | E |
# | $10^15$ | peta | P |
# | $10^12$ | tera | T |
# | $10^9$ | giga | G |
# | $10^6$ | mega | M |
# | $10^3$ | quilo | k |
# | $10^2$ | hecto | h |
# | $10^1$ | deca | da |
#
# - Submultiples ($Factor < 1$):
#
# | Factor | Prefix | Symbol |
# | :--- | :---: | ---: |
# | $10^{-1}$ | deci | d |
# | $10^{-2}$ | centi | c |
# | $10^{-3}$ | mili | m |
# | $10^{-6}$ | micro | μ |
# | $10^{-9}$ | nano | n |
# | $10^{-12}$ | pico | p |
# | $10^{-15}$ | femto | f |
# | $10^{-18}$ | ato | a |
# | $10^{-21}$ | zepto | z |
# | $10^{-24}$ | iocto | y |
#
# This program automates this logic by mapping the exponent associated with a given prefix and performing the corresponding calculations.
#
# ---

# %% [markdown]
# # How to use:
#
# 1. Run the cell below.
# 2. Enter the numerical value of the unit.
# 3. Enter the unit symbol (e.g., km, hg, ms) or its full name (kilometer, hectogram, millisecond).
# 4. The program automatically converts to the SI base unit.

# %%
unit = float(input("Define the value to be converted: "))
unit_name = input("Define the unit name to be converted: ")

if unit_name == "Decameter" or unit_name == "decameter" or unit_name == "dam":
    print(unit * 10, "meters")
if unit_name == "Decasecond" or unit_name == "decasecond" or unit_name == "das":
    print(unit * 10, "seconds")
if unit_name == "Decagram" or unit_name == "decagram" or unit_name == "dag":
    print(unit / 100, "kilograms")

if unit_name == "Hectometer" or unit_name == "hectometer" or unit_name == "hm":
    print(unit * 100, "meters")
if unit_name == "Hectosecond" or unit_name == "hectosecond" or unit_name == "hs":
    print(unit * 100, "seconds")
if unit_name == "Hectogram" or unit_name == "hectogram" or unit_name == "hg":
    print(unit / 10, "kilograms")

if unit_name == "kilometer" or unit_name == "Kilometer" or unit_name == "km":
    print(unit * 1000, "meters")
if unit_name == "Kilosecond" or unit_name == "kilosecond" or unit_name == "ks":
    print(unit * 1000, "seconds")
if unit_name == "Kilogram" or unit_name == "kilogram" or unit_name == "kg":
    print(unit / 1, "kilograms")

if unit_name == "Megameter" or unit_name == "megameter" or unit_name == "Mm":
    print(unit * 1000000, "meters")
if unit_name == "Megasecond" or unit_name == "megasecond" or unit_name == "Ms":
    print(unit * 1000000, "seconds")
if unit_name == "Megagram" or unit_name == "megagram" or unit_name == "Mg":
    print(unit * 1000, "kilograms")

if unit_name == "Gigameter" or unit_name == "gigameter" or unit_name == "Gm":
    print(unit * 1000000000, "meters")
if unit_name == "Gigasecond" or unit_name == "gigasecond" or unit_name == "Gs":
    print(unit * 1000000000, "seconds")
if unit_name == "Gigagram" or unit_name == "gigagram" or unit_name == "Gg":
    print(unit * 1000000, "kilograms")

if unit_name == "Tetrameter" or unit_name == "tetrameter" or unit_name == "Tm":
    print(unit * 1000000000000, "meters")
if unit_name == "Tetrasecond" or unit_name == "tetrasecond" or unit_name == "Ts":
    print(unit * 1000000000000, "seconds")
if unit_name == "Tetragram" or unit_name == "tetragram" or unit_name == "Tg":
    print(unit * 1000000000, "kilograms")

if unit_name == "Petameter" or unit_name == "petameter" or unit_name == "Pm":
    print(unit * 1000000000000000, "meters")
if unit_name == "Petasecond" or unit_name == "petasecond" or unit_name == "Ps":
    print(unit * 1000000000000000, "seconds")
if unit_name == "Petagram" or unit_name == "petagram" or unit_name == "Pg":
    print(unit * 1000000000000, "kilograms")

if unit_name == "Exameter" or unit_name == "exameter" or unit_name == "Em":
    print(unit * 1000000000000000000, "meters")
if unit_name == "Exasecond" or unit_name == "exasecond" or unit_name == "Es":
    print(unit * 1000000000000000000, "seconds")
if unit_name == "Exagram" or unit_name == "eexagram" or unit_name == "Eg":
    print(unit * 1000000000000000, "kilograms")

if unit_name == "Zetameter" or unit_name == "zetameter" or unit_name == "Zm":
    print(unit * 1000000000000000000000, "meters")
if unit_name == "Zetasecond" or unit_name == "zetasecond" or unit_name == "Zs":
    print(unit * 1000000000000000000000, "seconds")
if unit_name == "Zetagram" or unit_name == "zetagram" or unit_name == "Zg":
    print(unit * 1000000000000000000, "kilograms")

if unit_name == "Iotameter" or unit_name == "iotameter" or unit_name == "Ym":
    print(unit * 1000000000000000000000000, "meters")
if unit_name == "Iotasecond" or unit_name == "iotasecond" or unit_name == "Ys":
    print(unit * 1000000000000000000000000, "seconds")
if unit_name == "Iotagram" or unit_name == "iotagram" or unit_name == "Yg":
    print(unit * 1000000000000000000000, "kilograms")

if unit_name == "Decimeter" or unit_name == "decimeter" or unit_name == "dm":
    print(unit / 10, "meters")
if unit_name == "Decisecond" or unit_name == "decisecond" or unit_name == "ds":
    print(unit / 10, "seconds")
if unit_name == "Decigram" or unit_name == "decigram" or unit_name == "dg":
    print(unit / 10000, "kilograms")

if unit_name == "Centimeter" or unit_name == "centimeter" or unit_name == "cm":
    print(unit / 100, "meters")
if unit_name == "Centisecond" or unit_name == "centisecond" or unit_name == "cs":
    print(unit / 100, "seconds")
if unit_name == "Centigram" or unit_name == "centigram" or unit_name == "cg":
    print(unit / 100000, "kilograms")

if unit_name == "Milimeter" or unit_name == "milimeter" or unit_name == "mm":
    print(unit / 1000, "meters")
if unit_name == "Milisecond" or unit_name == "milisecond" or unit_name == "ms":
    print(unit / 1000, "seconds")
if unit_name == "Miligram" or unit_name == "miligram" or unit_name == "mg":
    print(unit / 1000000, "kilograms")

if unit_name == "Micrometer" or unit_name == "micrometer" or unit_name == "μm":
    print(unit / 1000000, "meters")
if unit_name == "Microsecond" or unit_name == "microsecond" or unit_name == "μs":
    print(unit / 1000000, "seconds")
if unit_name == "Microgram" or unit_name == "microgram" or unit_name == "μg":
    print(unit / 1000000000, "kilograms")

if unit_name == "Nanometer" or unit_name == "nanometer" or unit_name == "nm":
    print(unit / 1000000000, "meters")
if unit_name == "Nanosecond" or unit_name == "nanosecond" or unit_name == "ns":
    print(unit / 1000000000, "seconds")
if unit_name == "Nanogram" or unit_name == "nanogram" or unit_name == "ng":
    print(unit / 1000000000000, "kilograms")

if unit_name == "Picometer" or unit_name == "picometer" or unit_name == "pm":
    print(unit / 1000000000000, "meters")
if unit_name == "Picosecond" or unit_name == "picosecond" or unit_name == "ps":
    print(unit / 1000000000000, "seconds")
if unit_name == "Picogram" or unit_name == "picogram" or unit_name == "pg":
    print(unit / 1000000000000000, "kilograms")

if unit_name == "Femtometer" or unit_name == "femtometer" or unit_name == "fm":
    print(unit / 1000000000000000, "meters")
if unit_name == "Femtosecond" or unit_name == "femtosecond" or unit_name == "fs":
    print(unit / 1000000000000000, "seconds")
if unit_name == "Femtogram" or unit_name == "femtogram" or unit_name == "fg":
    print(unit / 1000000000000000000, "kilograms")

if unit_name == "Atometer" or unit_name == "atometer" or unit_name == "am":
    print(unit / 1000000000000000000, "meters")
if unit_name == "Atosecond" or unit_name == "atosecond" or unit_name == "as":
    print(unit / 1000000000000000000, "seconds")
if unit_name == "Atogram" or unit_name == "atogram" or unit_name == "ag":
    print(unit / 1000000000000000000000, "kilograms")

if unit_name == "Zeptometer" or unit_name == "zeptometer" or unit_name == "zm":
    print(unit / 1000000000000000000000, "meters")
if unit_name == "Zeptosecond" or unit_name == "zeptosecond" or unit_name == "zs":
    print(unit / 1000000000000000000000, "seconds")
if unit_name == "Zeptogram" or unit_name == "zeptogram" or unit_name == "zg":
    print(unit / 1000000000000000000000000, "kilograms")

if unit_name == "Ioctometer" or unit_name == "ioctometer" or unit_name == "ym":
    print(unit / 1000000000000000000000, "meters")
if unit_name == "Ioctosecond" or unit_name == "ioctosecond" or unit_name == "ys":
    print(unit / 1000000000000000000000, "seconds")
if unit_name == "Ioctogram" or unit_name == "ioctogram" or unit_name == "yg":
    print(unit / 1000000000000000000000000, "kilograms")
# Out:
# Define the value to be converted:  10
# Define the unit name to be converted:  ns
# 1e-08 seconds

# %% [markdown]
# # Interpretation
# It can be seen that each prefix corresponds to a specific power of 10
#
# ---
# # Conclusion
# All units of measurement can be converted using their prefixes.
#
# ---
