# %% [markdown]
# <div align="center">
#
# # Applied propositional logic - Compound propositions
# </div>
#
# ## Objective
#
# ---
#
# ## Theory

# %% [markdown]
# # Interpretation
#
# # Conclusion
# ---
